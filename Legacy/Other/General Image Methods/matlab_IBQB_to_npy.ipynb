# %%
import numpy as np
from scipy.io import loadmat

# Load the .mat file
mat_data = loadmat('/Users/henryschnieders/Desktop/Research/0813/averaged_background.mat')

# Select the specific variable(s) you want to save, for example:
dataIB = mat_data['IB']
dataQB = mat_data['QB']

# Save the data as a .npy file
np.save('/Users/henryschnieders/Desktop/Research/My work/Data/noise_IB.npy', dataIB)
np.save('/Users/henryschnieders/Desktop/Research/My work/Data/noise_QB.npy', dataQB)

# %%
import numpy as np

# Example list of arrays with different shapes
frames = [np.random.rand(100, 100), np.random.rand(200, 150), np.random.rand(120, 120)]

# Convert the list to a NumPy array of objects
frames_as_objects = np.array(frames, dtype=object)

# Save the array of objects
np.save('frames.npy', frames_as_objects)

# Load the data back
loaded_frames = np.load('frames.npy', allow_pickle=True)

# Verify the shapes
for i, frame in enumerate(loaded_frames):
    print(f"Frame {i} shape: {frame.shape}")

# %%
import pickle
import numpy as np

# Example list of arrays with different shapes
frames = [np.random.rand(100, 100), np.random.rand(200, 150), np.random.rand(120, 120)]

# Save using pickle
with open('frames.pkl', 'wb') as f:
    pickle.dump(frames, f)

# Load the data back
with open('frames.pkl', 'rb') as f:
    loaded_frames = pickle.load(f)

loaded_frames[1][2:4]


# Verify the shapes

# for i, frame in enumerate(loaded_frames):
#     print(f"Frame {i} shape: {frame.shape}")

# %%
filename = '/Users/henryschnieders/Desktop/Research/My work/Data/MYVID_frames.npy'
Amplitude = np.load(filename)
Amplitude.shape
